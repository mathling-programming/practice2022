# %% [markdown]
# Не получилось сделать сортировку (п. 4), но надеюсь, что остальные пункты подойдут, хотя я и знаю, что код громоздкий и, скорее всего, не соответствует тому, что должно быть. Тем не менее, он работает.
#
# Также прошу прощения за повторный запрос. Не заметила ошибку, пока не загрузила.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Загрузка и просмотр файлов (п. 1–2)

# %%
df1 = pd.read_csv("text.csv")

# %%
df1
# Out:
#        WORDNO          WORD
# 0           1    katekizmas
# 1           2          arba
# 2           3       mokslas
# 3           4    kiekvienam
# 4           5  krikščioniui
# ...       ...           ...
# 16575   16576         amžių
# 16576   16577        amžinų
# 16577   16578             ,
# 16578   16579          amen
# 16579   16580             .
#
# [16580 rows x 2 columns]

# %%
df2 = pd.read_csv("vocab.csv")

# %%
df2
# Out:
#           WORD  POS
# 0          ***  ***
# 1            ,    -
# 2            -    -
# 3            .    -
# 4            ?    -
# ...        ...  ...
# 3963      žymę  NaN
# 3964  žyminame    V
# 3965   žynauja    V
# 3966    žyvate  NaN
# 3967    žyvato  NaN
#
# [3968 rows x 2 columns]

# %% [markdown]
# # Соединение по столбцу WORD (п. 3)

# %%
df3 = pd.merge(df1, df2, on="WORD")

# %%
df3 = pd.merge(df1, df2, how="inner", on="WORD")

# %%
df3
# Out:
#        WORDNO               WORD  POS
# 0           1         katekizmas  NaN
# 1           2               arba   KO
# 2         678               arba   KO
# 3         702               arba   KO
# 4         837               arba   KO
# ...       ...                ...  ...
# 19417   16543          pataisyti    V
# 19418   16552            pildymo  NaN
# 19419   16556         atitraukti    V
# 19420   16562  didėsės?didesnės?  NaN
# 19421   16567        nuplatinimo  NaN
#
# [19422 rows x 3 columns]

# %% [markdown]
# # Группировка по полю POS (п. 5)

# %%
df4 = df3.groupby('POS')

# %% [markdown]
# # Попытка подсчёта, сохранение таблицы и графиков (п. 6–8)

# %%
for i in df4.groups: # каждая группа из списка
    df5 = df4.get_group(i) # датафрейм для каждой группы
    wl = [] # список для длин
    for w in df5['WORD']: # каждое слово из столбца
        wl.append(len(w))
    wl_mean = mean(wl)
    df5['W_LENGTH'] = wl # столбец с длиной слова
    df6 = df5['W_LENGTH'].rolling(window=10).mean() # пункт 6
    df7 = df6.to_frame()
    df7.plot()
    if i == '***':
        i = "asterisk"
    elif i == '???':
        i = "qm" 
    elif i == 'PTK???':
        i = "PTKqm"
    plt.savefig(f'{i}.png')  # пункт 7
    plt.show()
    df7.to_html(f'p6_table_{i}.html') # пункт 8
# Out:
# C:\Users\a_utk\AppData\Local\Temp\ipykernel_16852\2761757915.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['W_LENGTH'] = wl # столбец с длиной слова
# C:\Users\a_utk\AppData\Local\Temp\ipykernel_16852\2761757915.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['W_LENGTH'] = wl # столбец с длиной слова
# C:\Users\a_utk\AppData\Local\Temp\ipykernel_16852\2761757915.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# # Оставшиеся черновики

# %%
# # предыдущая версия с номерными названиями. оставлю на всякий случай
# n = 0
# for i in df4.groups: # каждая группа из списка
#     df5 = df4.get_group(i) # датафрейм для каждой группы
#     wl = [] # список для длин
#     for w in df5['WORD']: # каждое слово из столбца
#         wl.append(len(w))
#     wl_mean = mean(wl)
#     df5['W_LENGTH'] = wl # столбец с длиной слова
#     df6 = df5['W_LENGTH'].rolling(window=10).mean()
#     df7 = df6.to_frame()
#     df7.plot()
#     plt.savefig(f'{n}.png')  # пункт 7
#     plt.show()
#     df7.to_html(f'p6_table_{n}.html') # пункт 8
#     n += 1

# %%
# первый вариант, работает, но со строками. оставлю для подстраховки

# from statistics import mean
# for i in df4.groups: # каждая группа из списка
#     df5 = df4.get_group(i) # датафрейм для каждой группы
#     wl = [] # список для длин
#     for w in df5['WORD']: # каждое слово из столбца
#         wl.append(len(w))
#     wl_mean = mean(wl)
#     print ('Группа: ', i)
#     print ('Среднее:', wl_mean)
#     print('Cкользящие средние: \n', pd.Series(wl).rolling(window=3).mean(), '\n')
#     print('='*30, '\n')
